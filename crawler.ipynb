# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchAttributeException
from selenium.common.exceptions import NoSuchWindowException
import time
from random import randint

# use PhantomJS driver
driver = webdriver.PhantomJS()

# jandan boring pics
url = "http://jandan.net/pic/page-"
links=[]
for i in range(250):
    if i % 10 == 0:
        time.sleep(randint(1,11))
    try:
        driver.get(url+str(i))
        # now fetch all links
        eles = driver.find_elements_by_class_name("view_img_link")
        print ('{} pics for page {}.'.format(len(eles), i))
        for e in eles:
            try:
                links.append(e.get_attribute("href"))
            except NoSuchAttributeException:
                pass
        #driver.close()
    except NoSuchWindowException:
        #driver.close()
        pass
driver.close()
with open ('/Users/admin/Desktop/jandan-links.txt', 'w') as f:
    for l in links:
        f.write(l + '¥n')
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# 21 pics for page 0.
# 25 pics for page 1.
# 35 pics for page 2.
# 27 pics for page 3.
# 27 pics for page 4.
# 29 pics for page 5.
# 39 pics for page 6.
# 26 pics for page 7.
# 26 pics for page 8.
# 33 pics for page 9.
# 25 pics for page 10.
# 30 pics for page 11.
# 27 pics for page 12.
# 38 pics for page 13.
# 36 pics for page 14.
# 28 pics for page 15.
# 27 pics for page 16.
# 26 pics for page 17.
# 26 pics for page 18.
# 28 pics for page 19.
# 33 pics for page 20.
# 37 pics for page 21.
# 34 pics for page 22.
# 25 pics for page 23.
# 35 pics for page 24.
# 30 pics for page 25.
# 39 pics for page 26.
# 26 pics for page 27.
# 34 pics for page 28.
# 25 pics for page 29.
# ...

# %%
# 20180321 @Colt updated jandan now cannot locate specific page
# so we have to retrieve page number one by one
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchAttributeException
from selenium.common.exceptions import NoSuchWindowException
import time
from random import randint

# use PhantomJS driver
driver = webdriver.PhantomJS('/home/john/pkgs/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')

# jandan boring pics
url = "http://jandan.net/pic"
links = []

driver.get(url)
test = driver.find_elements_by_class_name('previous-comment-page')
for t in test:
    links.append(t.get_attribute("href").replace("#comments", ""))
    
print (links)
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# ['http://jandan.net/pic/page-50623868', 'http://jandan.net/pic/page-50623868']
